# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # CÓDIGOS

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

# %%
dados = pd.read_csv(url_dados , compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {'droga' : 'composto'}

# %%
dados.rename(columns = mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
sns.set()
plt.figure(figsize = (10,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos', {'fontsize': 15})
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['mean'].hist(bins= 30)

# %%
dados.loc[:, 'c-0':'c-99'].describe()
# Out:
#                 c-0           c-1  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      -0.355156     -0.455359  ...     -0.470252     -0.301505
# std        1.752565      2.004962  ...      1.834828      1.407918
# min      -10.000000    -10.000000  ...    -10.000000    -10.000000
# 25%       -0.549300     -0.538425  ...     -0.592600     -0.562900
# 50%       -0.009000      0.009800  ...      0.014000     -0.019500
# 75%        0.448975      0.476875  ...      0.461275      0.438650
# max        3.365000      3.915000  ...      3.111000      3.805000
#
# [8 rows x 100 columns]

# %%
dados.loc[:, 'c-0':'c-99'].describe().T['mean'].hist(bins= 30)

# %%
sns.boxplot(x = 'g-0' , data = dados)

# %%
plt.figure(figsize = (10,8))
##Aula2
sns.boxplot(y = 'g-0' , x = 'tratamento', data = dados)

# %% [markdown]
# # Desafios

# %% [markdown]
# ###Desafio 01: Ordenar o gráfico countplot
#
# ###Desafio 02: Melhorar a visualização alterando tamanho da fonte...
#
# ###Desafio 03: Plotar os histogramas com seaborn
#
# ###Desafio 04: Estudar sobre as estatíticas retornadas no .describe()
#
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.
#
# ###Desafio 06: Fazer outras análises com o boxplot e até com o histograma.
#
# ###Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# # Desafio 1

# %%
dataset = dados.query('composto in @cod_compostos')
dataset
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dataset['composto'].value_counts().sort_values(ascending = False)
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %%
order = dataset['composto'].value_counts(ascending=False).index
order
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
sns.set()
plt.figure(figsize = (10,6))
ax = sns.countplot(x = 'composto', data =  dados.query('composto in @cod_compostos'), order = order)
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# # Desafio 2

# %%
x = 'composto'
y = dados.query('composto in @cod_compostos')

# %%
sns.set()
plt.figure(figsize = (10,6))
ax = sns.countplot(x = x, data = y, order = order, palette='pastel')
ax.set_title('Top 5 compostos', {'fontsize': 20})
plt.xlabel("Composto", size=12)
plt.ylabel("Quantidade", size= 12)
plt.show()

# %% [markdown]
# # Desafio 3

# %% [markdown]
# Abaixo, plotei os dois histogramas e suas curvas de densidade referentes aos desvios-padrões dos tipos c e g

# %%
g = dados.loc[:, 'g-0':'g-771'].describe().T
g
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g-0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g-1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g-2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %%
g['std'].mean()
# Out:
# 1.189367950499471

# %%
c = dados.loc[:, 'c-0':'c-99'].describe().T
c
# Out:
#         count      mean       std   min       25%      50%       75%    max
# c-0   23814.0 -0.355156  1.752565 -10.0 -0.549300 -0.00900  0.448975  3.365
# c-1   23814.0 -0.455359  2.004962 -10.0 -0.538425  0.00980  0.476875  3.915
# c-2   23814.0 -0.480542  2.039346 -10.0 -0.550375 -0.00400  0.460575  2.970
# c-3   23814.0 -0.377666  1.554583 -10.0 -0.601975 -0.03905  0.413100  2.408
# c-4   23814.0 -0.493552  2.091888 -10.0 -0.559975  0.01140  0.470300  4.555
# ...       ...       ...       ...   ...       ...      ...       ...    ...
# c-95  23814.0 -0.353726  1.629291 -10.0 -0.567975 -0.01025  0.444750  2.814
# c-96  23814.0 -0.463485  2.059725 -10.0 -0.552575 -0.00125  0.465225  3.505
# c-97  23814.0 -0.378241  1.703615 -10.0 -0.561000 -0.00680  0.446400  2.924
# c-98  23814.0 -0.470252  1.834828 -10.0 -0.592600  0.01400  0.461275  3.111
# c-99  23814.0 -0.301505  1.407918 -10.0 -0.562900 -0.01950  0.438650  3.805
#
# [100 rows x 8 columns]

# %%
c['std'].mean()
# Out:
# 1.8868361230012047

# %%
sns.set()
plt.figure(figsize = (14,6))
plt.subplot(1,2,1)
sns.histplot(x = 'std', data = g, kde = True, bins = 30)
plt.subplot(1,2,2)
sns.histplot(x = 'std', data = c, kde = True, bins = 30)
plt.show()

# %% [markdown]
# # Desafio 4

# %%
dados.loc[:, 'g-0':'g-771'].describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %% [markdown]
# **Count**: quantidade de amostras de dados. **Mean**: média aritmética dos dados analisados. **Std**: desvio-padrão dos dados, ou seja, o quando os dados estão afastados da média destas amostras. **Min**: menor valor da série. **Max**: maior valor da série. **25%**: primeiro quartil. **50%**: segundo quartil. **75%**: terceiro quartil. **Quartil**: divisão em 3 faixas de uma série em 4 partes iguais, ou seja, cada quartil possui 25% das amostras

# %% [markdown]
# # Desafio 5

# %% [markdown]
# O tamanho das visualizações nos permite ter maior clareza em algumas constatações estatísticas. Por exemplo, no boxplot abaixo (gráfico 1) podemos ver um pequeno "desalinhamento" entre as medianas - que se comprova nas tabelas (1 e 2) quando comparamos as médias. Outra informação claramente verificada é que o tratamento com droga possui muito mais outliers do que o com controle (gráfico 2), o que era esperado dado que o desvio-padrão de g-0 com droga é bem maior do que com controle (1.42 vs. 0.83)

# %% [markdown]
# **TABELA 1**

# %%
dados[dados['tratamento']=='com_droga']['g-0'].describe()
# Out:
# count    21948.000000
# mean         0.277675
# std          1.427121
# min         -5.513000
# 25%         -0.460925
# 50%          0.000000
# 75%          0.533925
# max         10.000000
# Name: g-0, dtype: float64

# %% [markdown]
# **TABELA 2**

# %%
dados[dados['tratamento']=='com_controle']['g-0'].describe()
# Out:
# count    1866.000000
# mean       -0.096364
# std         0.833248
# min        -4.859000
# 25%        -0.639000
# 50%        -0.132650
# 75%         0.408800
# max         4.670000
# Name: g-0, dtype: float64

# %% [markdown]
# **GRÁFICO 1**

# %%
plt.figure(figsize = (8,6))
sns.boxplot(y = 'g-0' , x = 'tratamento', data = dados)
plt.ylim(-3.0, 3.0)
# Out:
# (-3.0, 3.0)

# %% [markdown]
# **GRÁFICO 2**

# %%
plt.figure(figsize = (8,6))
sns.boxplot(y = 'g-0' , x = 'tratamento', data = dados)

# %% [markdown]
# Os boxplots acima confirmam o que havia sido plotado no desafio 3, onde constatamos que o desvio-padrão do tipo g é menor do que o do tipo c. Conforme calculado anteriormente, o std de g fica por volta de 1.2 e o de c, próximo de 1.9
#
# Importante ressaltar que os gráficos estão em mesma escala, para justamente expor esse 'desalinhamento' entre eles.

# %%
plt.figure(figsize = (14,6))
plt.subplot(1,2,1)
sns.boxplot(y = g['std'], )
plt.ylim(0.5,)
plt.subplot(1,2,2)
sns.boxplot(y = c['std'])
plt.ylim(0.5,)
# Out:
# (0.5, 2.3717204829851104)

# %% [markdown]
# # Desafio 6

# %%
dataset['composto'].value_counts().sort_values(ascending = False)
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %%
top5_drogas = list(pd.DataFrame(dados['composto'].value_counts().head(5)).index)
top5_drogas
# Out:
# ['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee']

# %%
d1 = dados[dados['composto']==top5_drogas[0]]
d1;

# %%
d1.loc[:, 'g-0':'g-771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g-0    1866.0 -0.096364  0.833248  -4.859 -0.639000 -0.13265  0.408800   4.670
# g-1    1866.0 -0.281979  0.905735  -3.341 -0.879675 -0.24255  0.320075   5.039
# g-2    1866.0 -0.037559  1.016181  -9.104 -0.589150 -0.08995  0.489725   6.000
# g-3    1866.0  0.090283  0.887971  -2.568 -0.434450  0.05950  0.525775  10.000
# g-4    1866.0 -0.267603  1.078825  -5.805 -0.906775 -0.29720  0.416800   5.543
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g-767  1866.0 -0.264098  0.934945  -5.667 -0.705175 -0.24285  0.294400   2.426
# g-768  1866.0 -0.242252  0.702359  -3.385 -0.658975 -0.26270  0.090350   5.076
# g-769  1866.0 -0.361357  1.006901 -10.000 -0.863000 -0.32895  0.258150   2.377
# g-770  1866.0  0.187241  0.908228  -5.189 -0.321000  0.24015  0.723675   5.739
# g-771  1866.0 -0.253532  1.000997 -10.000 -0.762975 -0.20655  0.303125   5.042
#
# [772 rows x 8 columns]

# %%
d2 = dados[dados['composto']==top5_drogas[1]]
d2;

# %%
d2.loc[:, 'g-0':'g-771'].describe().T
# Out:
#        count      mean       std     min      25%      50%       75%     max
# g-0    718.0  5.044589  1.951431   1.062  3.57100  4.82300  6.293250  10.000
# g-1    718.0  0.260397  1.480963  -5.737 -0.70665  0.33465  1.180250   5.033
# g-2    718.0  1.140843  1.115928  -3.991  0.45100  0.87775  1.595000   8.257
# g-3    718.0  0.935945  2.161260  -5.766 -0.52510  0.86015  2.106250  10.000
# g-4    718.0  2.308726  1.791805  -3.003  1.10600  2.15150  3.352250  10.000
# ...      ...       ...       ...     ...      ...      ...       ...     ...
# g-767  718.0  0.179758  2.667162 -10.000 -1.65000  0.36655  2.210250   6.317
# g-768  718.0  1.889490  2.197518  -4.269  0.36015  1.51500  3.265000  10.000
# g-769  718.0 -0.845217  1.630691 -10.000 -1.62625 -0.68220  0.190275   4.046
# g-770  718.0 -3.925835  2.196652 -10.000 -5.28550 -3.68400 -2.473500  10.000
# g-771  718.0  3.791735  2.710517 -10.000  2.48625  3.72050  5.276500  10.000
#
# [772 rows x 8 columns]

# %%
d3 = dados[dados['composto']==top5_drogas[2]]
d3;

# %%
d3.loc[:, 'g-0':'g-771'].describe().T
# Out:
#        count      mean       std    min       25%      50%       75%    max
# g-0    246.0  0.190695  0.781997 -1.551 -0.354025  0.16010  0.646825  3.226
# g-1    246.0 -0.353853  0.906119 -3.242 -0.900825 -0.29755  0.230225  2.400
# g-2    246.0 -0.074071  0.915628 -3.299 -0.530925 -0.07340  0.435925  3.383
# g-3    246.0  0.172826  0.813465 -2.058 -0.407500  0.14745  0.658550  5.794
# g-4    246.0  0.114649  1.081199 -2.884 -0.569825  0.09075  0.753500  5.410
# ...      ...       ...       ...    ...       ...      ...       ...    ...
# g-767  246.0 -1.084772  1.154076 -5.921 -1.507250 -0.98140 -0.413325  1.619
# g-768  246.0  0.033241  0.770474 -1.531 -0.444125 -0.03765  0.389025  4.092
# g-769  246.0 -0.032261  1.048483 -5.365 -0.495075  0.10485  0.627100  2.292
# g-770  246.0  0.045469  0.899302 -2.638 -0.488550  0.11250  0.579975  3.601
# g-771  246.0 -0.374916  1.193045 -6.099 -0.867225 -0.20720  0.315050  3.547
#
# [772 rows x 8 columns]

# %%
d4 = dados[dados['composto']==top5_drogas[3]]
d4;

# %%
d4.loc[:, 'g-0':'g-771'].describe().T
# Out:
#        count      mean       std     min      25%     50%      75%     max
# g-0    203.0  0.560480  1.530317 -2.6470 -0.59120  0.4409  1.56900  4.7140
# g-1    203.0 -0.281461  0.958957 -3.8780 -0.82300 -0.2634  0.45800  2.5570
# g-2    203.0  0.174264  0.963833 -4.4630 -0.37515  0.1478  0.61565  3.8320
# g-3    203.0  2.308259  1.126064 -0.1602  1.41900  2.3310  2.94300  5.4210
# g-4    203.0  0.323558  1.003874 -2.6300 -0.28215  0.3011  1.07800  2.5480
# ...      ...       ...       ...     ...      ...     ...      ...     ...
# g-767  203.0 -3.369522  1.146370 -7.6610 -4.06300 -3.1870 -2.60700 -0.5976
# g-768  203.0  0.669826  0.874487 -1.0210  0.09520  0.5216  1.10300  4.8470
# g-769  203.0  0.116259  1.126872 -5.1090 -0.44520  0.2291  0.90600  2.9780
# g-770  203.0 -0.614705  1.277357 -4.6060 -1.43600 -0.5002  0.30965  2.4620
# g-771  203.0  0.784260  1.049487 -4.9050  0.16080  0.7828  1.51650  5.6290
#
# [772 rows x 8 columns]

# %%
d5 = dados[dados['composto']==top5_drogas[4]]
d5;

# %%
d5.loc[:, 'g-0':'g-771'].describe().T
# Out:
#        count      mean       std    min       25%      50%       75%    max
# g-0    202.0  2.089169  1.554749 -0.892  0.861850  1.97750  3.009500  6.501
# g-1    202.0 -0.367460  1.028959 -3.991 -0.946600 -0.26205  0.256775  4.180
# g-2    202.0  0.255831  1.055365 -3.902 -0.352400  0.22440  0.822850  3.807
# g-3    202.0 -0.068789  0.864474 -2.495 -0.523475 -0.16920  0.338250  5.558
# g-4    202.0 -0.538161  1.235323 -5.717 -1.178250 -0.48595  0.127450  4.087
# ...      ...       ...       ...    ...       ...      ...       ...    ...
# g-767  202.0 -0.427226  0.903617 -5.097 -0.944375 -0.37750  0.067200  2.778
# g-768  202.0 -0.262711  0.636505 -1.962 -0.681075 -0.24170  0.078750  1.881
# g-769  202.0 -0.142253  0.881075 -4.687 -0.693775 -0.11875  0.422075  1.843
# g-770  202.0 -0.416474  1.135333 -5.848 -1.012925 -0.38195  0.228375  5.260
# g-771  202.0 -0.062663  1.132410 -4.740 -0.540275  0.03405  0.625200  3.470
#
# [772 rows x 8 columns]

# %%
plt.figure(figsize = (20,10))
plt.subplot(2,3,1)
sns.histplot(x = d1.loc[:, 'g-0':'g-771'].describe().T['mean'])
plt.subplot(2,3,2)
sns.histplot(x = d2.loc[:, 'g-0':'g-771'].describe().T['mean'])
plt.subplot(2,3,3)
sns.histplot(x = d3.loc[:, 'g-0':'g-771'].describe().T['mean'])
plt.subplot(2,3,4)
sns.histplot(x = d4.loc[:, 'g-0':'g-771'].describe().T['mean'])
plt.subplot(2,3,5)
sns.histplot(x = d5.loc[:, 'g-0':'g-771'].describe().T['mean'])

# %%
plt.figure(figsize = (14,6))
plt.subplot(1,5,1)
sns.boxplot(y = d1.loc[:, 'g-0':'g-771'].describe().T['std'])
plt.subplot(1,5,2)
sns.boxplot(y = d2.loc[:, 'g-0':'g-771'].describe().T['std'])
plt.subplot(1,5,3)
sns.boxplot(y = d3.loc[:, 'g-0':'g-771'].describe().T['std'])
plt.subplot(1,5,4)
sns.boxplot(y = d4.loc[:, 'g-0':'g-771'].describe().T['std'])
plt.subplot(1,5,5)
sns.boxplot(y = d5.loc[:, 'g-0':'g-771'].describe().T['std'])

# %%
d1.loc[:, 'g-0':'g-771'].describe().T.mean()['std']
# Out:
# 0.9227289805170891

# %%
d2.loc[:, 'g-0':'g-771'].describe().T.mean()['std']
# Out:
# 2.0983526935537293

# %%
d3.loc[:, 'g-0':'g-771'].describe().T.mean()['std']
# Out:
# 0.9736700651398557

# %%
d4.loc[:, 'g-0':'g-771'].describe().T.mean()['std']
# Out:
# 1.1380970434014026

# %%
d5.loc[:, 'g-0':'g-771'].describe().T.mean()['std']
# Out:
# 1.0057799386892259

# %% [markdown]
# No desafio 6 separei os top 5 compostos utilizados no estudo. O que se percebe pelo histograma e o boxplot é que a distribuição deles são centradas ao redor de 0, mas o composto #2 (**87d714366**) tem desvio bem maior em relação aos outros 4 compostos. Talvez seja um bom composto mais interessante para analisarmos mais de perto.

# %% [markdown]
# # Desafio 7

# %% [markdown]
# Como já citado no fim da aula 1, a droga do tipo **cacb2b860** representa mais de 50% do total das amostras. A distribuição normal do tipo g-0 se comporta de forma padrão com o eixo centrado mais ao 0 e poucas dispersões nas caudas - o máximo é maior que o mínimo em módulo, portanto, uma cauda mais a direita do que a esquerda. Os tipos c tem maiores desvios do que os tipos g. Aparentemente, a variável "com droga" em tipo de tratamento possui mais outliers do que a variável "com controle".
#
# Outra constatação feita é que, no desafio 6, o composto **87d714366** se mostrou com maiores dispersões do que os outros 4 dentre os 5 mais utilizados no estudo.
